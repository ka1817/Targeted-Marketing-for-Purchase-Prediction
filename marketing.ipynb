# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:\\Users\\saipr\\Downloads\\a1_Dataset_10Percent.xlsx")

# %%
df
# Out:
#              ID  DemAffl  DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0     NaN             NaN       NaN         NaN
# 1       8415498     15.0     NaN             NaN         M         NaN
# 2      12107603      NaN     NaN             NaN         M    Midlands
# 3      14400995      8.0    28.0             NaN         F         NaN
# 4      28724674     14.0    67.0             NaN       NaN         NaN
# ...         ...      ...     ...             ...       ...         ...
# 22218  52830893     13.0    49.0               B         M  South East
# 22219  52834058     13.0    65.0               B         F  South East
# 22220  52834376     15.0    73.0               D         U  South East
# 22221  52837057      9.0    70.0               B         F       North
# 22222  52838096     11.0    66.0               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df.shape
# Out:
# (22223, 11)

# %%
df.columns
# Out:
# Index(['ID', 'DemAffl', 'DemAge', 'DemClusterGroup', 'DemGender', 'DemReg',
#        'DemTVReg', 'LoyalClass', 'LoyalSpend', 'LoyalTime', 'TargetBuy'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22223 entries, 0 to 22222
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               22223 non-null  int64
#  1   DemAffl          21138 non-null  float64
#  2   DemAge           20715 non-null  float64
#  3   DemClusterGroup  21549 non-null  object
#  4   DemGender        19711 non-null  object
#  5   DemReg           21758 non-null  object
#  6   DemTVReg         21758 non-null  object
#  7   LoyalClass       22223 non-null  object
#  8   LoyalSpend       22223 non-null  float64
#  9   LoyalTime        21942 non-null  float64
#  10  TargetBuy        22223 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.9+ MB

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass'], dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['ID', 'DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime', 'TargetBuy'], dtype='object')

# %%
df
# Out:
#              ID  DemAffl  DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0     NaN             NaN       NaN         NaN
# 1       8415498     15.0     NaN             NaN         M         NaN
# 2      12107603      NaN     NaN             NaN         M    Midlands
# 3      14400995      8.0    28.0             NaN         F         NaN
# 4      28724674     14.0    67.0             NaN       NaN         NaN
# ...         ...      ...     ...             ...       ...         ...
# 22218  52830893     13.0    49.0               B         M  South East
# 22219  52834058     13.0    65.0               B         F  South East
# 22220  52834376     15.0    73.0               D         U  South East
# 22221  52837057      9.0    70.0               B         F       North
# 22222  52838096     11.0    66.0               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df.isnull().sum()
# Out:
# ID                    0
# DemAffl            1085
# DemAge             1508
# DemClusterGroup     674
# DemGender          2512
# DemReg              465
# DemTVReg            465
# LoyalClass            0
# LoyalSpend            0
# LoyalTime           281
# TargetBuy             0
# dtype: int64

# %%
##percentage of null values in each feature
df.isnull().sum()/df.shape[0]
# Out:
# ID                 0.000000
# DemAffl            0.048823
# DemAge             0.067858
# DemClusterGroup    0.030329
# DemGender          0.113036
# DemReg             0.020924
# DemTVReg           0.020924
# LoyalClass         0.000000
# LoyalSpend         0.000000
# LoyalTime          0.012645
# TargetBuy          0.000000
# dtype: float64

# %%
sns.distplot(df['DemAge'])
# Out:
# C:\Users\saipr\AppData\Local\Temp\ipykernel_33192\524151144.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['DemAge'])
# <Axes: xlabel='DemAge', ylabel='Density'>

# %%
sns.boxplot(df['DemAge'])
# Out:
# <Axes: ylabel='DemAge'>

# %%
df['DemAge'].skew()
# Out:
# np.float64(-0.07983041684947201)

# %%
df['DemAge'].describe()
# Out:
# count    20715.000000
# mean        53.797152
# std         13.206048
# min         18.000000
# 25%         44.000000
# 50%         54.000000
# 75%         64.000000
# max         79.000000
# Name: DemAge, dtype: float64

# %%
sns.histplot(df['DemAge'])
# Out:
# <Axes: xlabel='DemAge', ylabel='Count'>

# %%
df['DemAge'].corr(df['TargetBuy'])
# Out:
# np.float64(-0.3025403991550228)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_yes=df[df['TargetBuy']==1]
df_no=df[df['TargetBuy']==0]

# %%
fig,ax=plt.subplots(figsize=(14,7))
sns.distplot(df_yes['DemAge'],label=1,hist=False,rug=False,ax=ax)
sns.distplot(df_no['DemAge'],label=0,hist=False,rug=False,ax=ax)
plt.legend()

# %% [markdown]
# most of the customers are buying products  are in the age 30-40

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
# Number of features in the DataFrame
n_features = len(df.columns)

# Set up the subplot grid (1 row and n_features columns)
fig, axes = plt.subplots(1, n_features, figsize=(5 * n_features, 5))

# Loop through each feature and create a scatter plot
for idx, feature in enumerate(df.columns):
    if feature != 'DemAge':  # Skip 'DemAge' on the y-axis
        sns.scatterplot(x=df['DemAge'], y=df[feature], ax=axes[idx])
        axes[idx].set_title(f'DemAge vs {feature}')

plt.show()

# %%
for i in df.select_dtypes(include='number').columns:
    responde=df['DemAge'].corr(df[i])
    print(f"{responde}")
# Out:
# 0.006649299943467645
# -0.13776651012670144
# 1.0
# 0.2684335296735586
# 0.20722088487520907
# -0.3025403991550228

# %%
for i in df.select_dtypes(include='number').columns:
    if i != 'DemAge':  # Skip 'DemAge' if it is included in the columns selected
        responde = df['DemAge'].corr(df[i])
        print(f"Correlation between 'DemAge' and '{i}': {responde}")
# Out:
# Correlation between 'DemAge' and 'ID': 0.006649299943467645
# Correlation between 'DemAge' and 'DemAffl': -0.13776651012670144
# Correlation between 'DemAge' and 'LoyalSpend': 0.2684335296735586
# Correlation between 'DemAge' and 'LoyalTime': 0.20722088487520907
# Correlation between 'DemAge' and 'TargetBuy': -0.3025403991550228

# %%
##Filling the missing values
df['DemAge']=df['DemAge'].fillna(df['DemAge'].mean())

# %%
df['DemAge'].mean()
# Out:
# np.float64(53.797151822350955)

# %% [markdown]
# ## The second Feature

# %%
df['DemAffl'].isnull().sum()
# Out:
# np.int64(1085)

# %%
df['DemAffl'].describe()
# Out:
# count    21138.000000
# mean         8.711893
# std          3.421125
# min          0.000000
# 25%          6.000000
# 50%          8.000000
# 75%         11.000000
# max         34.000000
# Name: DemAffl, dtype: float64

# %%
sns.distplot(df['DemAffl'])
# Out:
# <Axes: xlabel='DemAffl', ylabel='Density'>

# %%
sns.boxplot(df['DemAffl'])
# Out:
# <Axes: ylabel='DemAffl'>

# %%
sns.histplot(df['DemAffl'])
# Out:
# <Axes: xlabel='DemAffl', ylabel='Count'>

# %%
df['DemAffl'].skew()
# Out:
# np.float64(0.8916837237684435)

# %%
# Calculate Q1, Q3, and IQR
Q1 = df['DemAffl'].quantile(0.25)
Q3 = df['DemAffl'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Identify outliers
outliers = df[(df['DemAffl'] < lower_bound) | (df['DemAffl'] > upper_bound)]

# %%
outliers
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 106    17674107     23.0  34.000000               F         M         NaN
# 135    26541149     25.0  53.797152               B         F         NaN
# 233    39823284     30.0  36.000000             NaN         F       North
# 275    50553892     19.0  53.797152               B         U         NaN
# 316     2034743     19.0  38.000000             NaN         F    Midlands
# ...         ...      ...        ...             ...       ...         ...
# 22103  52582156     19.0  57.000000               F         F    Scottish
# 22138  52665442     22.0  28.000000               C         F  South East
# 22162  52710480     19.0  68.000000               B         M       North
# 22174  52724139     20.0  77.000000               C         F    Midlands
# 22207  52791510     20.0  33.000000               F         M    Midlands
#
#            DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
# Remove rows with outliers
df = df[(df['DemAffl'] >= lower_bound) & (df['DemAffl'] <= upper_bound)]

# %%
sns.boxplot(df['DemAffl'])
# Out:
# <Axes: ylabel='DemAffl'>

# %%
df['DemAffl'].skew()
# Out:
# np.float64(0.3810238282358333)

# %%
df['DemAffl'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_yes=df[df['TargetBuy']==1]
df_no=df[df['TargetBuy']==0]

# %%
fig,ax=plt.subplots(figsize=(14,7))
sns.distplot(df_yes['DemAffl'],label=1,hist=False,rug=False,ax=ax)
sns.distplot(df_no['DemAffl'],label=0,hist=False,rug=False,ax=ax)
plt.legend()

# %%
df_no['DemAffl'].skew()
# Out:
# np.float64(0.33757395032952553)

# %% [markdown]
# ## Third Feature

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152             NaN       NaN         NaN
# 1       8415498     15.0  53.797152             NaN         M         NaN
# 3      14400995      8.0  28.000000             NaN         F         NaN
# 4      28724674     14.0  67.000000             NaN       NaN         NaN
# 6      43266179      7.0  41.000000             NaN       NaN         NaN
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df['DemClusterGroup'].isnull().sum()
# Out:
# np.int64(621)

# %%
df['DemClusterGroup'].value_counts()
# Out:
# DemClusterGroup
# C    4298
# D    4122
# B    3904
# F    3699
# E    2434
# A    1751
# U      52
# Name: count, dtype: int64

# %%
# Fill missing values with the mode (most frequent category)
mode_value = df['DemClusterGroup'].mode()[0]
df['DemClusterGroup'] = df['DemClusterGroup'].fillna(mode_value)

# %%
df['DemClusterGroup'].value_counts()
# Out:
# DemClusterGroup
# C    4919
# D    4122
# B    3904
# F    3699
# E    2434
# A    1751
# U      52
# Name: count, dtype: int64

# %%
sns.countplot(x=df['DemClusterGroup'])
# Out:
# <Axes: xlabel='DemClusterGroup', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the values and index (categories) from the value_counts
values = df['DemClusterGroup'].value_counts().values
index = df['DemClusterGroup'].value_counts().index

# Create the pie chart using matplotlib
plt.figure(figsize=(7, 7))
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Categories in DemClusterGroup')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
sns.heatmap(df.select_dtypes(include='number').corr())
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot for two categorical features
sns.countplot(x='DemClusterGroup', hue='TargetBuy', data=df)
plt.title('Count of Categories in DemClusterGroup by TargetBuy')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a contingency table (cross-tabulation)
crosstab = pd.crosstab(df['DemClusterGroup'], df['TargetBuy'])

# Create a heatmap to visualize the contingency table
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='g', linewidths=0.5)
plt.title('Contingency Table between DemClusterGroup and TargetBuy')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a facet grid for the categorical features
g = sns.FacetGrid(df, col="DemClusterGroup", hue="TargetBuy", height=5)
g.map(sns.countplot, 'DemClusterGroup')
g.add_legend()
plt.show()

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C       NaN         NaN
# 1       8415498     15.0  53.797152               C         M         NaN
# 3      14400995      8.0  28.000000               C         F         NaN
# 4      28724674     14.0  67.000000               C       NaN         NaN
# 6      43266179      7.0  41.000000               C       NaN         NaN
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C       NaN         NaN
# 1       8415498     15.0  53.797152               C         M         NaN
# 3      14400995      8.0  28.000000               C         F         NaN
# 4      28724674     14.0  67.000000               C       NaN         NaN
# 6      43266179      7.0  41.000000               C       NaN         NaN
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %% [markdown]
# ## Feature DemGender

# %%
df['DemGender'].value_counts()
# Out:
# DemGender
# F    11371
# M     5462
# U     1672
# Name: count, dtype: int64

# %%
ax=sns.countplot(x=df['DemGender'])
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x=df['DemGender'],hue=df['TargetBuy'])
for bars in ax.containers:
    ax.bar_label(bars)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a contingency table (cross-tabulation)
crosstab = pd.crosstab(df['DemGender'], df['TargetBuy'])

# Create a heatmap to visualize the contingency table
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='g', linewidths=0.5)
plt.title('Contingency Table between DemGender and TargetBuy')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the values and index (categories) from the value_counts
values = df['DemGender'].value_counts().values
index = df['DemGender'].value_counts().index

# Create the pie chart using matplotlib
plt.figure(figsize=(7, 7))
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Categories in Gender')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
df['DemGender'].isnull().sum()
# Out:
# np.int64(2376)

# %%
df['DemGender']=df['DemGender'].fillna(df['DemGender'].mode()[0])

# %%
df['DemGender'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Plotting proportions using Seaborn
category_counts = df['DemGender'].value_counts()
category_percentages = (category_counts / category_counts.sum()) * 100

sns.countplot(x='DemGender', data=df)
for i, count in enumerate(category_counts):
    percentage = category_percentages.iloc[i]
    plt.text(i, count + 5, f'{percentage:.1f}%', ha='center')

plt.title('Proportion of Each Class')
plt.show()

# %%
from scipy.stats import chi2_contingency

# Perform the Chi-Square test
contingency_table = pd.crosstab(df['DemGender'], df['TargetBuy'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-Square Statistic: 686.7021325658471
# P-value: 7.665254128545767e-150

# %%
# Visualize how the 'age' varies by 'class'
sns.boxplot(x='DemGender', y='DemAge', data=df)
plt.title('Age Distribution by Class')
plt.show()

# %%
# Cross-tabulate data to get proportions
contingency_table = pd.crosstab(df['DemGender'], df['TargetBuy'], normalize='index')

# Plot the stacked bar plot
contingency_table.plot(kind='bar', stacked=True)
plt.title('Gender by Target BUy')
plt.ylabel('Proportion')
plt.show()

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F         NaN
# 1       8415498     15.0  53.797152               C         M         NaN
# 3      14400995      8.0  28.000000               C         F         NaN
# 4      28724674     14.0  67.000000               C         F         NaN
# 6      43266179      7.0  41.000000               C         F         NaN
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F         NaN
# 1       8415498     15.0  53.797152               C         M         NaN
# 3      14400995      8.0  28.000000               C         F         NaN
# 4      28724674     14.0  67.000000               C         F         NaN
# 6      43266179      7.0  41.000000               C         F         NaN
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
sns.countplot(x=df['DemReg'])
# Out:
# <Axes: xlabel='DemReg', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the values and index (categories) from the value_counts
values = df['DemReg'].value_counts().values
index = df['DemReg'].value_counts().index

# Create the pie chart using matplotlib
plt.figure(figsize=(7, 7))
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Categories in DemReg')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a contingency table (cross-tabulation)
crosstab = pd.crosstab(df['DemReg'], df['TargetBuy'])

# Create a heatmap to visualize the contingency table
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='g', linewidths=0.5)
plt.title('Contingency Table between DemGender and TargetBuy')
plt.show()

# %%
df['DemReg'].isnull().sum()
# Out:
# np.int64(435)

# %%
df['DemReg']=df['DemReg'].fillna(df['DemReg'].mode()[0])

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F  South East
# 1       8415498     15.0  53.797152               C         M  South East
# 3      14400995      8.0  28.000000               C         F  South East
# 4      28724674     14.0  67.000000               C         F  South East
# 6      43266179      7.0  41.000000               C         F  South East
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
sns.distplot(df['LoyalSpend'])
# Out:
# <Axes: xlabel='LoyalSpend', ylabel='Density'>

# %%
df['LoyalSpend'].skew()
# Out:
# np.float64(8.163530314965291)

# %%
df['LoyalSpend'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(df['LoyalSpend'])
# Out:
# <Axes: ylabel='LoyalSpend'>

# %%
df['LoyalSpend']=df['LoyalSpend'].fillna(df['LoyalSpend'].median())

# %%
sns.boxplot(df['LoyalSpend'])
# Out:
# <Axes: ylabel='LoyalSpend'>

# %%
sns.barplot(x=df['TargetBuy'],y=df['LoyalSpend'],ci='sd')
# Out:
# <Axes: xlabel='TargetBuy', ylabel='LoyalSpend'>

# %%
sns.rugplot(df['LoyalSpend'])
plt.show()

# %%
sns.kdeplot(df['LoyalSpend'])
# Out:
# <Axes: xlabel='LoyalSpend', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
df['LoyalSpend'].corr(df['LoyalTime'])
# Out:
# np.float64(0.03333405702869473)

# %%
sns.violinplot(x=df['LoyalSpend'])
plt.show()

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F  South East
# 1       8415498     15.0  53.797152               C         M  South East
# 3      14400995      8.0  28.000000               C         F  South East
# 4      28724674     14.0  67.000000               C         F  South East
# 6      43266179      7.0  41.000000               C         F  South East
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df['DemTVReg']=df['DemTVReg'].fillna(df['DemTVReg'].mode()[0])

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F  South East
# 1       8415498     15.0  53.797152               C         M  South East
# 3      14400995      8.0  28.000000               C         F  South East
# 4      28724674     14.0  67.000000               C         F  South East
# 6      43266179      7.0  41.000000               C         F  South East
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
sns.distplot(df['LoyalTime'])
# Out:
# <Axes: xlabel='LoyalTime', ylabel='Density'>

# %%
df['LoyalTime'].skew()
# Out:
# np.float64(2.269366783503493)

# %%
df['LoyalTime']=df['LoyalTime'].fillna(df['LoyalTime'].mean())

# %%
df
# Out:
#              ID  DemAffl     DemAge DemClusterGroup DemGender      DemReg  \
# 0      17147654      5.0  53.797152               C         F  South East
# 1       8415498     15.0  53.797152               C         M  South East
# 3      14400995      8.0  28.000000               C         F  South East
# 4      28724674     14.0  67.000000               C         F  South East
# 6      43266179      7.0  41.000000               C         F  South East
# ...         ...      ...        ...             ...       ...         ...
# 22218  52830893     13.0  49.000000               B         M  South East
# 22219  52834058     13.0  65.000000               B         F  South East
# 22220  52834376     15.0  73.000000               D         U  South East
# 22221  52837057      9.0  70.000000               B         F       North
# 22222  52838096     11.0  66.000000               B         F       North
#
#          DemTVReg LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# ...

# %%
df.isnull().sum()
# Out:
# ID                 0
# DemAffl            0
# DemAge             0
# DemClusterGroup    0
# DemGender          0
# DemReg             0
# DemTVReg           0
# LoyalClass         0
# LoyalSpend         0
# LoyalTime          0
# TargetBuy          0
# dtype: int64

# %%
X=df.drop('TargetBuy',axis=1)
y=df['TargetBuy']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (15660, 10) (15660,)
# (5221, 10) (5221,)

# %%
X_train.select_dtypes('number').columns
# Out:
# Index(['ID', 'DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime'], dtype='object')

# %%
X_test.select_dtypes('object').columns
# Out:
# Index(['DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass'], dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from joblib import dump

# Assuming `df` is your DataFrame
# Define feature columns and target column
X = df[['DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime', 'DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass']]
y = df['TargetBuy']  # Replace with the actual target column name

# Define numeric and categorical columns
numeric_features = ['DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime']
categorical_features = ['DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define preprocessing for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine them into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Define classifiers
classifiers = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVC': SVC(random_state=42)
}

# Hyperparameter tuning for each model
param_grids = {
    'RandomForest': {
        'clf__n_estimators': [50, 100],
        'clf__max_depth': [None, 10, 20],
        'clf__min_samples_split': [2, 5]
    },
    'GradientBoosting': {
        'clf__n_estimators': [50, 100],
        'clf__learning_rate': [0.05, 0.1, 0.2],
        'clf__max_depth': [3, 4, 5]
    },
    'SVC': {
        'clf__C': [0.1, 1, 10],
        'clf__gamma': ['scale', 'auto'],
        'clf__kernel': ['linear', 'rbf']
    }
}

# Create pipelines for each classifier
pipelines = {
    name: Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('clf', clf)
    ]) for name, clf in classifiers.items()
}

# Hyperparameter tuning and model training
best_models = {}

for name, pipeline in pipelines.items():
    print(f"Training {name}...")
    grid_search = GridSearchCV(pipeline, param_grids[name], cv=StratifiedKFold(5), n_jobs=-1, verbose=1)
    grid_search.fit(X_train, y_train)
    best_models[name] = grid_search.best_estimator_

    # Evaluate the best model
    y_pred = grid_search.best_estimator_.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{name} - Accuracy: {accuracy:.4f}")
    
    # Save the best model
    dump(grid_search.best_estimator_, f"{name}_best_model.joblib")
    print(f"{name} model saved!")

print("Training and saving complete.")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# RandomForest - Accuracy: 0.8008
# RandomForest model saved!
# Training GradientBoosting...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GradientBoosting - Accuracy: 0.8026
# GradientBoosting model saved!
# Training SVC...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# SVC - Accuracy: 0.8000
# SVC model saved!
# Training and saving complete.

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# Assuming `df` is your DataFrame
# Define feature columns and target column
X = df[['DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime', 'DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass']]
y = df['TargetBuy']  # Replace with the actual target column name

# Define numeric and categorical columns
numeric_features = ['DemAffl', 'DemAge', 'LoyalSpend', 'LoyalTime']
categorical_features = ['DemClusterGroup', 'DemGender', 'DemReg', 'DemTVReg', 'LoyalClass']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define preprocessing for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine them into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Define classifiers
classifiers = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVC': SVC(random_state=42)
}

# Hyperparameter tuning for each model
param_grids = {
    'RandomForest': {
        'clf__n_estimators': [50, 100],
        'clf__max_depth': [None, 10, 20],
        'clf__min_samples_split': [2, 5]
    },
    'GradientBoosting': {
        'clf__n_estimators': [50, 100],
        'clf__learning_rate': [0.05, 0.1, 0.2],
        'clf__max_depth': [3, 4, 5]
    },
    'SVC': {
        'clf__C': [0.1, 1, 10],
        'clf__gamma': ['scale', 'auto'],
        'clf__kernel': ['linear', 'rbf']
    }
}

# Create pipelines for each classifier
pipelines = {
    name: Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('clf', clf)
    ]) for name, clf in classifiers.items()
}

# Hyperparameter tuning and model training
best_models = {}

# Start an MLflow experiment
mlflow.set_experiment("Classifier_Models")

for name, pipeline in pipelines.items():
    print(f"Training {name}...")
    
    # Start a new MLflow run
    with mlflow.start_run() as run:
        grid_search = GridSearchCV(pipeline, param_grids[name], cv=StratifiedKFold(5), n_jobs=-1, verbose=1,scoring='f1')
        grid_search.fit(X_train, y_train)
        
        # Log parameters
        mlflow.log_params(grid_search.best_params_)
        
        # Log metrics
        y_pred = grid_search.best_estimator_.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)
        
        # Save the best model using MLflow
        mlflow.sklearn.log_model(grid_search.best_estimator_, f"{name}_best_model")
        
        best_models[name] = grid_search.best_estimator_

        print(f"{name} - Accuracy: {accuracy:.4f}")
        print(f"Logged {name} model in MLflow!")

print("Training, hyperparameter tuning, and model logging complete.")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 2025/01/28 10:35:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# RandomForest - Accuracy: 0.7954
# Logged RandomForest model in MLflow!
# Training GradientBoosting...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# 2025/01/28 10:35:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# GradientBoosting - Accuracy: 0.8014
# Logged GradientBoosting model in MLflow!
# Training SVC...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# ...

# %%
df['TargetBuy'].value_counts()
# Out:
# TargetBuy
# 0    15916
# 1     4965
# Name: count, dtype: int64

# %%
import mlflow
logged_model = 'runs:/ca7bd24d0dea4cca8c1da381a754cd3e/GradientBoosting_best_model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
pred_ml=loaded_model.predict(X_test)

# %%
accuracy_score(pred_ml,y_test)
# Out:
# 0.8014365522745411
